# %% [markdown]
# ## This notebook demonstrates how to build a simple video classification training pipeline using `PyTorchVideo` models, datasets and transforms.
#
#
# ### We will be using a `3D ResNet` for the model and the `Kinetics` dataset and a standard video transform augmentation recipe.
#
# ***

# %% [markdown]
# ## 1. Prepare the dataset.
# Setup the PyTorchVideo Kinetics data loader using a `pytorch_lightning.LightningDataModule` This is a wrapper that defines the train, validation and test data partitions.
#
# The list of videos found on the Kinetics website can be found [here.](https://deepmind.com/research/open-source/kinetics)
#
# You will then need the official [download script](https://github.com/activitynet/ActivityNet/tree/master/Crawler/Kinetics) to download the videos.
#
# Once the videos are downloaded, point the `pytorchvideo.data.Kinetics data path` argument to the folder of classes.
#
# There are a few arguments that are more specific to PyTorch datasets:
#
# - `video_sampler`: It defines the order to sample a video at each iteration.
# - `clip_sampler`: Defines how to sample a clip from the chosen video at each iteration.
# -`transform`: This provides a way to apply user-defined data preprocessing or augmentation before batch collating by the PyTorch data loader.

# %%
# !pip install pytorch-lightning pytorchvideo torchvision torchrec torchaudio
# Out:
# Requirement already satisfied: pytorch-lightning in /home/debonair/anaconda3/lib/python3.9/site-packages (1.7.7)
# Requirement already satisfied: pytorchvideo in /home/debonair/anaconda3/lib/python3.9/site-packages (0.1.5)
# Requirement already satisfied: torchvision in /home/debonair/anaconda3/lib/python3.9/site-packages (0.13.1)
# Requirement already satisfied: torchrec in /home/debonair/anaconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: torchaudio in /home/debonair/anaconda3/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (0.9.3)
# Requirement already satisfied: tqdm>=4.57.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (4.64.0)
# Requirement already satisfied: torch>=1.9.* in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (1.12.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (4.1.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (2.10.1)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (0.3.2)
# Requirement already satisfied: numpy>=1.17.2 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (1.21.5)
# Requirement already satisfied: packaging>=17.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: PyYAML>=5.4 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (5.4.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorch-lightning) (2022.2.0)
# Requirement already satisfied: iopath in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorchvideo) (0.1.10)
# Requirement already satisfied: av in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorchvideo) (9.2.0)
# Requirement already satisfied: parameterized in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorchvideo) (0.8.1)
# Requirement already satisfied: fvcore in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorchvideo) (0.1.5.post20220512)
# Requirement already satisfied: networkx in /home/debonair/anaconda3/lib/python3.9/site-packages (from pytorchvideo) (2.7.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: requests in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: idna in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (3.3)
# Requirement already satisfied: portalocker in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.5.1)
# Requirement already satisfied: cmake in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (3.24.1.1)
# Requirement already satisfied: fbgemm-gpu in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.2.0)
# Requirement already satisfied: pyre-extensions==0.0.27 in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.0.27)
# Requirement already satisfied: hypothesis in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (6.55.0)
# Requirement already satisfied: websocket-client in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.58.0)
# Requirement already satisfied: pandas in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.4.2)
# Requirement already satisfied: Cython in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.29.28)
# Requirement already satisfied: MarkupSafe in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.0.1)
# Requirement already satisfied: python-dateutil in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.8.2)
# Requirement already satisfied: sortedcontainers in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.4.0)
# Requirement already satisfied: pyarrow in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (7.0.0)
# Requirement already satisfied: typing-inspect in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.8.0)
# Requirement already satisfied: filelock in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (3.6.0)
# Requirement already satisfied: Jinja2 in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.11.3)
# Requirement already satisfied: six in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.16.0)
# Requirement already satisfied: arrow in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.2.2)
# Requirement already satisfied: docstring-parser in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.8.1)
# Requirement already satisfied: pytz in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2021.3)
# Requirement already satisfied: charset-normalizer in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.0.4)
# Requirement already satisfied: docker in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (6.0.0)
# Requirement already satisfied: scikit-build in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.15.0)
# Requirement already satisfied: torchx-nightly in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2022.10.1)
# Requirement already satisfied: distro in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.7.0)
# Requirement already satisfied: urllib3 in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.26.9)
# Requirement already satisfied: certifi in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2021.10.8)
# Requirement already satisfied: mypy-extensions in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.4.3)
# Requirement already satisfied: pyparsing in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (2.4.7)
# Requirement already satisfied: tabulate in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (0.8.9)
# Requirement already satisfied: usort in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.0.5)
# Requirement already satisfied: attrs in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (21.4.0)
# Requirement already satisfied: ninja in /home/debonair/anaconda3/lib/python3.9/site-packages (from torchrec) (1.10.2.4)
# Requirement already satisfied: aiohttp in /home/debonair/anaconda3/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.42.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.3.4)
# Requirement already satisfied: wheel>=0.26 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (61.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.8.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (3.19.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from tensorboard>=2.9.1->pytorch-lightning) (2.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/debonair/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/debonair/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning) (3.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/debonair/anaconda3/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/debonair/anaconda3/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/debonair/anaconda3/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: yacs>=0.1.6 in /home/debonair/anaconda3/lib/python3.9/site-packages (from fvcore->pytorchvideo) (0.1.8)
# Requirement already satisfied: termcolor>=1.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from fvcore->pytorchvideo) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/debonair/anaconda3/lib/python3.9/site-packages (from hypothesis->torchrec) (1.0.0rc9)
# Requirement already satisfied: click>=7.0.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from usort->torchrec) (8.0.4)
# Requirement already satisfied: toml>=0.10.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from usort->torchrec) (0.10.2)
# Requirement already satisfied: LibCST>=0.3.7 in /home/debonair/anaconda3/lib/python3.9/site-packages (from usort->torchrec) (0.4.7)
# Requirement already satisfied: stdlibs>=2021.4.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from usort->torchrec) (2022.6.8)
# Requirement already satisfied: moreorless>=0.3.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from usort->torchrec) (0.4.0)
# Requirement already satisfied: trailrunner>=1.0 in /home/debonair/anaconda3/lib/python3.9/site-packages (from usort->torchrec) (1.2.1)
# Requirement already satisfied: pathspec>=0.8.1 in /home/debonair/anaconda3/lib/python3.9/site-packages (from trailrunner>=1.0->usort->torchrec) (0.10.1)

# %%
import os
import pytorch_lightning
import pytorchvideo.data
import torch.utils.data

from pytorchvideo.transforms import (
    ApplyTransformToKey, 
    Normalize, 
    RandomShortSideScale,
    RemoveKey,
    ShortSideScale,
    UniformTemporalSubsample
)


import torchvision
from torchvision.transforms import (
    Compose, 
    Lambda, 
    RandomCrop,
    RandomHorizontalFlip
)

# %% [markdown]
# #2. Transforms.
# `PyTorchVideo` datasets take a `transform` callable argument that defines custom processing, e.g. `augmentations, normalization` that is applied to each clip.
#
# `pytorchvideo.data.Kinetics` clips have the following dictionary format:
#
#
# ```
# {
#   'video': <video_tensor>     #Shape: (C, T, H, W)
#   'audio': <audio_tensor>     #Shape: (S)
#   'label' : <action_label>    #Integer defining class annotation.
#   'video_name': <video_path>  #Video file path stem.
#   'video_index': <video_id>   #Index of video used by the sampler.
#   'clip_index': <clip_id>     #Index of the clip sampled within the video.
# }
# ```

# %%
class KineticsDataModule(pytorch_lightning.LightningDataModule):
    #Dataset configuration.
    _DATA_PATH = '~/.torch/datasets/'
    _CLIP_DURATION = 2 #The duration of sampled clip for each video.
    _BATCH_SIZE = 8
    _NUM_WORKERS = 7 #The number of parallel processes fetcing data.

    def train_dataloader(self):
        global _DATA_PATH
        '''
        Creates the Kinetics train partition from the list of video labels.
        Add transform that subsamples and normalizes the video before applying
        the scale, crop and flip augmentations.
        '''
        train_transform = Compose(
            [
                ApplyTransformToKey(
                    key = 'video',
                    transform = Compose(
                        [
                         UniformTemporalSubsample(8),
                         Lambda(lambda x: x / 255.0),
                         Normalize((0.45, 0.45, 0.45), (0.225, 0.225, 0.225)),
                         RandomShortSideScale(min_size = 256, max_size = 320),
                         RandomCrop(244),
                         RandomHorizontalFlip(p = 0.5)
                        ]
                    ),
                ),
            ]
        )

        train_dataset = torchvision.datasets.Kinetics(root = _DATA_PATH, frames_per_clip = 10, 
                                                  num_classes = '101', split = 'train',
                                                  step_between_clips = 1, transform = train_transform, 
                                                  download = False, num_download_workers = 4, num_workers = 4)

        train_dataset = pytorchvideo.data.Kinetics(
            clip_sampler = pytorchvideo.data.make_clip_sampler('random', self._CLIP_DURATION),
            decode_audio = False)

        # train_dataset = pytorchvideo.data.Kinetics(
        #     data_path = os.path.join(self._DATA_PATH, 'train.csv'),
        #     clip_sampler = pytorchvideo.data.make_clip_sampler('random', self._CLIP_DURATION),
        #     transform = train_transform
            # )

        return torch.utils.data.DataLoader(
                train_dataset, 
        batch_size = self._BATCH_SIZE, 
        num_workers = self._NUM_WORKERS
    )
    
    
    
    def val_dataloader(self):        
        '''Creates the Kinetics validation partition from the list of video labels.'''
        val_dataset = torchvision.datasets.Kinetics(root = './', frames_per_clip = 10, 
                                                      num_classes = '101', split = 'test',
                                                      step_between_clips = 1, 
                                                      download = False, num_download_workers = 4, num_workers = 4)

        val_dataset = pytorchvideo.data.Kinetics(
            clip_sampler = pytorchvideo.data.make_clip_sampler('uniform', self._CLIP_DURATION),
            decode_audio = False
        )
        # val_dataset = pytorchvideo.data.Kinetics(
        #     data_path = os.path.join(self._DATA_PATH, 'val'),
        #     clip_sampler = pytorchvideo.data.make_clip_sampler('uniform', self._CLIP_DURATION),
        #     decode_audio = False
        # )

        return torch.utils.data.DataLoader(
            val_dataset, 
            batch_size = self._BATCH_SIZE,
            num_workers = self._NUM_WORKERS
        )

# %% [markdown]
# #3. Model.
# All PytorchVideo models and layers can be built with simple, reproducible factory functions.
#
# We call this a `flat` model interface since the arguments do not require hierarchical configurations to be used.

# %%
import pytorchvideo.models.resnet

def make_kinetics_resnet():
    return pytorchvideo.models.resnet.create_resnet(
      input_channel = 3, #RGB input for kinetics.
      model_depth = 50, #ResNet 50
      model_num_class = 101, #Kinetics has 400 classes, so we need the final head to align
      norm = nn.BatchNorm3d,
      activation = nn.ReLU
    )

# %% [markdown]
# #4. Putting it all together,
#
# We create a `pytorch_lightning.LightningModule` that defines the train and validation step code and the optimizer.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class VideoClassificationLightningModule(pytorch_lightning.LightningModule):
    def __init__(self):
        super().__init__()
        self.model = make_kinetics_resnet()

    def forward(self, x):
        return self.model(x)


    def training_step(self, batch, batch_idx):
        #The model expects a video tensor of shape (B, C, T, H, W), which is 
        #the format provided by the dataset.
        y_hat = self.model(batch['video'])

        #Compute cross-entropy loss, loss.backkwards will be called under the hood by
        #pytorchlightning after being returned from this method.
        loss = F.cross_entropy(y_hat, batch['label'])

        #Log the train loss to TensorBoard.
        self.log('train_loss', loss.item())

        return loss

    def validation_step(self, batch, batch_idx):
        y_hat = self.model(batch['video'])
        loss = F.cross_entropy(y_hat, batch['label'])
        self.log('val_loss', loss)

        return loss

    def configure_optimizers(self):
        '''
        Setup the Adam optimizer. This function also can return a learning_rate scheduler 
        which is usually for training video models.
        '''
        return torch.optim.Adam(self.parameters(), lr = 1e-1)

# %%
def train():
    classification_module = VideoClassificationLightningModule()
    data_module = KineticsDataModule()
    trainer = pytorch_lightning.Trainer()
    trainer.fit(classification_module, data_module)

train()
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/debonair/anaconda3/lib/python3.9/site-packages/pytorch_lightning/loops/utilities.py:89: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
# Missing logger folder: /home/debonair/Documents/Jupyter/Computer Vision/Projects/Video-recognition-for-ASL/notebooks/lightning_logs
#
#   | Name  | Type | Params
# -------------------------------
# 0 | model | Net  | 31.9 M
# -------------------------------
# 31.9 M    Trainable params
# 0         Non-trainable params
# 31.9 M    Total params
# 127.441   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 7>()
#       4     trainer = pytorch_lightning.Trainer()
#       5     trainer.fit(classification_module, data_module)
# ----> 7 train()
#
# Input In [18], in train()
#       3 data_module = KineticsDataModule()
#       4 trainer = pytorch_lightning.Trainer()
# ----> 5 trainer.fit(classification_module, data_module)
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:696, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     677 r"""
#     678 Runs the full optimization routine.
#     679
#    (...)
#     693     datamodule: An instance of :class:`~pytorch_lightning.core.datamodule.LightningDataModule`.
#     694 """
#     695 self.strategy.model = model
# --> 696 self._call_and_handle_interrupt(
#     697     self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     698 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:650, in Trainer._call_and_handle_interrupt(self, trainer_fn, *args, **kwargs)
#     648         return self.strategy.launcher.launch(trainer_fn, *args, trainer=self, **kwargs)
#     649     else:
# --> 650         return trainer_fn(*args, **kwargs)
#     651 # TODO(awaelchli): Unify both exceptions below, where `KeyboardError` doesn't re-raise
#     652 except KeyboardInterrupt as exception:
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     731 ckpt_path = ckpt_path or self.resume_from_checkpoint
#     732 self._ckpt_path = self.__set_ckpt_path(
#     733     ckpt_path, model_provided=True, model_connected=self.lightning_module is not None
#     734 )
# --> 735 results = self._run(model, ckpt_path=self.ckpt_path)
#     737 assert self.state.stopped
#     738 self.training = False
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1166, in Trainer._run(self, model, ckpt_path)
#    1162 self._checkpoint_connector.restore_training_state()
#    1164 self._checkpoint_connector.resume_end()
# -> 1166 results = self._run_stage()
#    1168 log.detail(f"{self.__class__.__name__}: trainer tearing down")
#    1169 self._teardown()
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1252, in Trainer._run_stage(self)
#    1250 if self.predicting:
#    1251     return self._run_predict()
# -> 1252 return self._run_train()
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1274, in Trainer._run_train(self)
#    1271 self._pre_training_routine()
#    1273 with isolate_rng():
# -> 1274     self._run_sanity_check()
#    1276 # enable train mode
#    1277 self.model.train()
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1336, in Trainer._run_sanity_check(self)
#    1333 self._call_callback_hooks("on_sanity_check_start")
#    1335 # reload dataloaders
# -> 1336 val_loop._reload_evaluation_dataloaders()
#    1337 self.num_sanity_val_batches = [
#    1338     min(self.num_sanity_val_steps, val_batches) for val_batches in self.num_val_batches
#    1339 ]
#    1341 # run eval step
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/loops/dataloader/evaluation_loop.py:237, in EvaluationLoop._reload_evaluation_dataloaders(self)
#     235     dataloaders = self.trainer.test_dataloaders
#     236 elif self.trainer.val_dataloaders is None or self.trainer._data_connector._should_reload_val_dl:
# --> 237     self.trainer.reset_val_dataloader()
#     238     dataloaders = self.trainer.val_dataloaders
#     239 if dataloaders is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1932, in Trainer.reset_val_dataloader(self, model)
#    1926 if self.state.fn == TrainerFn.FITTING and (
#    1927     (self.sanity_checking and self.fit_loop.epoch_loop._should_check_val_epoch())
#    1928     or not self.sanity_checking
#    1929 ):
#    1930     self._last_val_dl_reload_epoch = self.current_epoch
# -> 1932 self.num_val_batches, self.val_dataloaders = self._data_connector._reset_eval_dataloader(
#    1933     RunningStage.VALIDATING, model=pl_module
#    1934 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:365, in DataConnector._reset_eval_dataloader(self, mode, model)
#     362 assert mode.evaluating or mode == RunningStage.PREDICTING
#     364 # always get the loaders first so we can count how many there are
# --> 365 dataloaders = self._request_dataloader(mode)
#     367 if self.trainer.overfit_batches > 0:
#     368     dataloaders = self._resolve_overfit_batches(dataloaders, mode)
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:453, in DataConnector._request_dataloader(self, stage)
#     446 source = getattr(self, f"_{stage.dataloader_prefix}_dataloader_source")
#     448 with _replace_dunder_methods(DataLoader, "dataset"), _replace_dunder_methods(BatchSampler):
#     449     # under this context manager, the arguments passed to `DataLoader.__init__` will be captured and saved as
#     450     # attributes on the instance in case the dataloader needs to be re-instantiated later by Lightning.
#     451     # Also, it records all attribute setting and deletion using patched `__setattr__` and `__delattr__`
#     452     # methods so that the re-instantiated object is as close to the original as possible.
# --> 453     dataloader = source.dataloader()
#     454 if isinstance(dataloader, tuple):
#     455     dataloader = list(dataloader)
#
# File ~/anaconda3/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:530, in _DataLoaderSource.dataloader(self)
#     528 if isinstance(self.instance, LightningDataModule):
#     529     method = getattr(self.instance, self.name)
# --> 530     return method()
#     532 return self.instance
#
# Input In [15], in KineticsDataModule.val_dataloader(self)
#      56 def val_dataloader(self):
#      57     '''Creates the Kinetics validation partition from the list of video labels.'''
# ---> 58     val_dataset = torchvision.datasets.Kinetics(root = './', frames_per_clip = 10,
#      59                                                   num_classes = '101', split = 'test',
#      60                                                   step_between_clips = 1,
#      61                                                   download = False, num_download_workers = 4, num_workers = 4)
#      63     val_dataset = pytorchvideo.data.Kinetics(
#      64         clip_sampler = pytorchvideo.data.make_clip_sampler('uniform', self._CLIP_DURATION),
#      65         decode_audio = False
#      66     )
#      67     # val_dataset = pytorchvideo.data.Kinetics(
#      68     #     data_path = os.path.join(self._DATA_PATH, 'val'),
#      69     #     clip_sampler = pytorchvideo.data.make_clip_sampler('uniform', self._CLIP_DURATION),
#      70     #     decode_audio = False
#      71     # )
#
# File ~/anaconda3/lib/python3.9/site-packages/torchvision/datasets/kinetics.py:116, in Kinetics.__init__(self, root, frames_per_clip, num_classes, split, frame_rate, step_between_clips, transform, extensions, download, num_download_workers, num_workers, _precomputed_metadata, _video_width, _video_height, _video_min_dimension, _audio_samples, _audio_channels, _legacy, output_format)
#      92 def __init__(
#      93     self,
#      94     root: str,
#    (...)
#     114
#     115     # TODO: support test
# --> 116     self.num_classes = verify_str_arg(num_classes, arg="num_classes", valid_values=["400", "600", "700"])
#     117     self.extensions = extensions
#     118     self.num_download_workers = num_download_workers
#
# File ~/anaconda3/lib/python3.9/site-packages/torchvision/datasets/utils.py:483, in verify_str_arg(value, arg, valid_values, custom_msg)
#     481         msg = "Unknown value '{value}' for argument {arg}. Valid values are {{{valid_values}}}."
#     482         msg = msg.format(value=value, arg=arg, valid_values=iterable_to_str(valid_values))
# --> 483     raise ValueError(msg)
#     485 return value
#
# ValueError: Unknown value '101' for argument num_classes. Valid values are {'400', '600', '700'}.
